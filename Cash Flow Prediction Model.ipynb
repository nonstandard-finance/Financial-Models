# %% [markdown]
# # PREPARING THE DATA
#
# THE FIRST BLOCKs OF CODE PREPARES THE DATA NEEDED TO BUILD THE MODEL. HERE WE GOT DATA FROM YAHOO FINANCE FROM PUBLIC COMPANIES AND CLEANED IT EXTRACTING THE KEY DETAILS WHICH WILL BE NEEDED. HOWEVER TO ENSURE ITS ROBUST ENOUGH WE SYNTHETICALLY CREATED DATA AND ADDED IT TO THE DATA. THE TOTAL DATA IS WHAT WILL BE USED

# %% [markdown]
# # IMPORTING THE NECCESSARY PACKAGES TO PREPARE THE DATA AND EXECUTE/MAKE A CASH FLOW PREDICTION MODEL

# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV, KFold
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.preprocessing import StandardScaler, PowerTransformer
from sklearn.metrics import mean_squared_error, r2_score
import pickle
import warnings
import yfinance as yf
import pandas as pd
import os
import time
import random
from sdv.single_table import GaussianCopulaSynthesizer
from sdv.metadata import SingleTableMetadata

# %% [markdown]
# # CREATING THE DATASET
#
# This block of code creates the necessary data which we will used in building the predictive model

# %%
# Creating the Function to fetch and save financial data from Yahoo Finance
def save_financial_data(ticker_symbol, start_year, end_year, output_dir, max_retries=3, retry_delay=5, quarterly=True):
    ticker = yf.Ticker(ticker_symbol)
    try:
        print(f"\nFetching data for ticker: {ticker_symbol}")
        company_dir = os.path.join(output_dir, ticker_symbol)
        os.makedirs(company_dir, exist_ok=True)
        company_dfs = {}
        for statement_type in ["balance_sheet", "income_stmt", "cashflow"]:
            for attempt in range(max_retries):
                try:
                    print(f"Attempting to retrieve {statement_type} (Attempt {attempt + 1}/{max_retries})...")
                    if quarterly:
                        statement = getattr(ticker, f"quarterly_{statement_type}")
                    else:
                        statement = getattr(ticker, statement_type)
                    if statement is not None and not statement.empty:
                        statement = statement.T
                        statement.index = pd.to_datetime(statement.index)
                        statement = statement.sort_index()
                        statement = statement[str(start_year):str(end_year)]
                        if not statement.empty:
                            company_dfs[statement_type] = statement
                            print(f"Retrieved {statement_type} data for {ticker_symbol}")
                            break
                        else:
                            print(f"No {statement_type} data found for {ticker_symbol}")
                            break
                except Exception as e:
                    print(f"Attempt {attempt + 1} failed for {statement_type} of {ticker_symbol}: {e}")
                    if attempt < max_retries - 1:
                        sleep_time = retry_delay + random.uniform(0, 3)
                        print(f"Retrying in {sleep_time:.2f} seconds...")
                        time.sleep(sleep_time)
            else:
                print(f"Failed to retrieve {statement_type} for {ticker_symbol} after {max_retries} attempts.")
        if company_dfs:
            combined_df = pd.concat(company_dfs, axis=1, keys=company_dfs.keys())
            combined_df.to_csv(os.path.join(company_dir, f"{ticker_symbol}_combined_financial_data.csv"))
            print(f"Combined data for {ticker_symbol} saved.")
        else:
            print(f"No financial data retrieved for {ticker_symbol}")
    except Exception as e:
        print(f"Error getting ticker data for {ticker_symbol}: {e}")

# Combining all company data into one file
def combine_all_company_data(data_dir, output_filename="combined_financial_data.csv", output_folder="csv_data"):
    os.makedirs(output_folder, exist_ok=True)
    combined_file_path = os.path.join(output_folder, output_filename)
    all_dfs = []
    for company_folder in os.listdir(data_dir):
        company_path = os.path.join(data_dir, company_folder)
        if os.path.isdir(company_path):
            for filename in os.listdir(company_path):
                if filename.endswith(".csv") and "combined_financial_data" in filename:
                    file_path = os.path.join(company_path, filename)
                    try:
                        df = pd.read_csv(file_path, index_col=0, header=[0, 1])
                        df.index = pd.to_datetime(df.index)
                        df['Company'] = company_folder
                        all_dfs.append(df)
                    except pd.errors.EmptyDataError:
                        print(f"Skipping empty file: {file_path}")
                    except Exception as e:
                        print(f"Error reading {file_path}: {e}")
    if all_dfs:
        combined_df = pd.concat(all_dfs, sort=True)
        combined_df.sort_index(inplace=True)
        combined_df.to_csv(combined_file_path)
        print(f"Combined data saved to {combined_file_path}")
    else:
        print("No CSV files found to combine.")

# Cleaning the financial data
def clean_financial_data(input_file, output_file, output_folder="csv_data"):
    try:
        os.makedirs(output_folder, exist_ok=True)
        output_file_path = os.path.join(output_folder, output_file)
        df = pd.read_csv(input_file, index_col=0, header=[0, 1])
        df.index = pd.to_datetime(df.index)
        key_metrics = [
            ('balance_sheet', 'Accounts Payable'),
            ('balance_sheet', 'Accounts Receivable'),
            ('income_stmt', 'Total Revenue'),
            ('income_stmt', 'Gross Profit'),
            ('income_stmt', 'Net Income'),
            ('cashflow', 'Operating Cash Flow'),
            ('cashflow', 'Investing Cash Flow'),
            ('cashflow', 'Financing Cash Flow'),
            ('cashflow', 'Change In Working Capital'),
        ]
        key_metrics = [col for col in key_metrics if col in df.columns]
        df = df.loc[:, key_metrics]
        df.columns = ['_'.join(col).strip() for col in df.columns.values]
        df.replace([np.inf, -np.inf], np.nan, inplace=True)
        df = df.dropna()
        df.to_csv(output_file_path)
        print(f"Cleaned financial data saved to {output_file_path}")
    except Exception as e:
        print(f"Error cleaning financial data: {e}")

# Generating synthetic data with 80% random replacement
def generate_synthetic_data_with_randomness_and_range(
    cleaned_file, num_rows=5000, min_value=100_000, max_value=1_000_000_000, 
    output_file="synthetic_financial_data.csv", output_folder="csv_data"
):
    try:
        os.makedirs(output_folder, exist_ok=True)
        cleaned_data = pd.read_csv(cleaned_file)
        cleaned_data = cleaned_data.select_dtypes(include=[np.number])  # Ensure numerical-only columns
        
        # Creating the metadata and synthesizer
        metadata = SingleTableMetadata()
        metadata.detect_from_dataframe(cleaned_data)
        synthesizer = GaussianCopulaSynthesizer(metadata)
        synthesizer.fit(cleaned_data)
        
        # Generating the synthetic data
        synthetic_data = synthesizer.sample(num_rows)
        
        # Applying 80% random replacement with constraints
        for column in synthetic_data.columns:
            synthetic_data[column] = synthetic_data[column].apply(
                lambda x: np.random.randint(min_value, max_value) if np.random.rand() < 0.8 else x
            )
            synthetic_data[column] = synthetic_data[column].clip(lower=min_value, upper=max_value)
        
        synthetic_data.to_csv(os.path.join(output_folder, output_file), index=False)
        print(f"Synthetic data (80% randomness with range constraints) saved to {output_folder}/{output_file}")
    except Exception as e:
        print(f"Error generating synthetic data with randomness and range: {e}")

# Combining the real and synthetic data
def combine_real_and_synthetic_data(cleaned_file, synthetic_file, output_file="combined_real_and_synthetic_data.csv", output_folder="csv_data"):
    try:
        os.makedirs(output_folder, exist_ok=True)
        cleaned_data = pd.read_csv(cleaned_file)
        synthetic_data = pd.read_csv(synthetic_file)
        combined_data = pd.concat([cleaned_data, synthetic_data], ignore_index=True)
        combined_data.to_csv(os.path.join(output_folder, output_file), index=False)
        print(f"Combined real and synthetic data saved to {output_folder}/{output_file}")
    except Exception as e:
        print(f"Error combining real and synthetic data: {e}")

# Executining the  pipeline
if __name__ == "__main__":
    dataset_folder = "Cash Flow Prediction Dataset"
    financial_data_folder = os.path.join(dataset_folder, "financial_data")
    csv_data_folder = os.path.join(dataset_folder, "csv_data")

    output_dir = financial_data_folder
    combined_file = "combined_financial_data.csv"
    cleaned_file = "cleaned_financial_data.csv"
    synthetic_file = "synthetic_financial_data.csv"
    combined_real_and_synthetic_file = "combined_real_and_synthetic_data.csv"

    companies = [
        {"symbol": "AAPL", "industry": "Tech"},
    {"symbol": "MSFT", "industry": "Tech"},
    {"symbol": "GOOG", "industry": "Tech"},
    {"symbol": "NVDA", "industry": "Tech"},
    {"symbol": "IBM", "industry": "Tech"},
    {"symbol": "ORCL", "industry": "Tech"},
    {"symbol": "JPM", "industry": "Banks"},
    {"symbol": "BAC", "industry": "Banks"},
    {"symbol": "WFC", "industry": "Banks"},
    {"symbol": "C", "industry": "Banks"},
    {"symbol": "GS", "industry": "Banks"},
    {"symbol": "MS", "industry": "Banks"},
    {"symbol": "XOM", "industry": "Oil"},
    {"symbol": "CVX", "industry": "Oil"},
    {"symbol": "SLB", "industry": "Oil"},
    {"symbol": "COP", "industry": "Oil"},
    {"symbol": "PG", "industry": "Consumer Goods"},
    {"symbol": "PEP", "industry": "Consumer Goods"},
    {"symbol": "KO", "industry": "Consumer Goods"},
    {"symbol": "CL", "industry": "Consumer Goods"},
    {"symbol": "UL", "industry": "Consumer Goods"},
    {"symbol": "PM", "industry": "Consumer Goods"},
    {"symbol": "CAT", "industry": "Industrials"},
    {"symbol": "LMT", "industry": "Industrials"},
    {"symbol": "BA", "industry": "Industrials"},
    {"symbol": "RTX", "industry": "Industrials"},
    {"symbol": "GE", "industry": "Industrials"},
    {"symbol": "HON", "industry": "Industrials"},
    {"symbol": "SPG", "industry": "Real Estate"},
    {"symbol": "PLD", "industry": "Real Estate"},
    {"symbol": "O", "industry": "Real Estate"},
    {"symbol": "EQR", "industry": "Real Estate"},
    {"symbol": "VNO", "industry": "Real Estate"},
    {"symbol": "BXP", "industry": "Real Estate"},
    {"symbol": "TSLA", "industry": "Automotive"},
    {"symbol": "F", "industry": "Automotive"},
    {"symbol": "GM", "industry": "Automotive"},
    {"symbol": "RIVN", "industry": "Automotive"},
    {"symbol": "TM", "industry": "Automotive"},
    {"symbol": "HMC", "industry": "Automotive"},
    {"symbol": "JNJ", "industry": "Healthcare"},
    {"symbol": "PFE", "industry": "Healthcare"},
    {"symbol": "MRK", "industry": "Healthcare"},
    {"symbol": "ABBV", "industry": "Healthcare"},
    {"symbol": "TMO", "industry": "Healthcare"},
    {"symbol": "DHR", "industry": "Healthcare"},
    {"symbol": "AMZN", "industry": "Retail"},
    {"symbol": "WMT", "industry": "Retail"},
    {"symbol": "TGT", "industry": "Retail"},
    {"symbol": "COST", "industry": "Retail"},
    {"symbol": "HD", "industry": "Retail"},
    {"symbol": "LOW", "industry": "Retail"},
    {"symbol": "DIS", "industry": "Entertainment"},
    {"symbol": "NFLX", "industry": "Entertainment"},
    {"symbol": "CMCSA", "industry": "Entertainment"},
    {"symbol": "VIA", "industry": "Entertainment"},
    {"symbol": "FOX", "industry": "Entertainment"},
    {"symbol": "SPOT", "industry": "Entertainment"},
    {"symbol": "V", "industry": "Financial Services"},
    {"symbol": "MA", "industry": "Financial Services"},
    {"symbol": "PYPL", "industry": "Financial Services"},
    {"symbol": "SQ", "industry": "Financial Services"},
    {"symbol": "AXP", "industry": "Financial Services"},
    {"symbol": "COF", "industry": "Financial Services"},
    {"symbol": "INTC", "industry": "Tech"},
    {"symbol": "AMD", "industry": "Tech"},
    {"symbol": "TSM", "industry": "Tech"},
    {"symbol": "ADBE", "industry": "Tech"},
    {"symbol": "CRM", "industry": "Tech"},
    {"symbol": "NOW", "industry": "Tech"},
    {"symbol": "META", "industry": "Tech"},
    {"symbol": "SNAP", "industry": "Tech"},
    {"symbol": "TWTR", "industry": "Tech"},
    {"symbol": "SHOP", "industry": "Tech"},
    {"symbol": "NKE", "industry": "Consumer Goods"},
    {"symbol": "ADDYY", "industry": "Consumer Goods"},
    {"symbol": "RL", "industry": "Consumer Goods"},
    {"symbol": "TIF", "industry": "Consumer Goods"},
    {"symbol": "UPS", "industry": "Logistics"},
    {"symbol": "FDX", "industry": "Logistics"},
    {"symbol": "DHL", "industry": "Logistics"},
    {"symbol": "CSX", "industry": "Logistics"},
    {"symbol": "NSC", "industry": "Logistics"},
    {"symbol": "UNP", "industry": "Logistics"},
    {"symbol": "SO", "industry": "Utilities"},
    {"symbol": "DUK", "industry": "Utilities"},
    {"symbol": "NEE", "industry": "Utilities"},
    {"symbol": "D", "industry": "Utilities"},
    {"symbol": "EXC", "industry": "Utilities"},
    {"symbol": "PPL", "industry": "Utilities"},
    {"symbol": "MCD", "industry": "Restaurants"}, 
    {"symbol": "YUM", "industry": "Restaurants"}, 
    {"symbol": "SBUX", "industry": "Restaurants"}, 
    {"symbol": "CMG", "industry": "Restaurants"}, 
    {"symbol": "MELI", "industry": "E-commerce"}, 
    {"symbol": "EBAY", "industry": "E-commerce"}, 
    {"symbol": "ETSY", "industry": "E-commerce"}, 
    {"symbol": "AZO", "industry": "Retail"}, 
    {"symbol": "TJX", "industry": "Retail"}, 
    {"symbol": "ROKU", "industry": "Entertainment"}, 
    {"symbol": "DISCA", "industry": "Entertainment"}, 
    {"symbol": "CHTR", "industry": "Telecommunications"}, 
    {"symbol": "T", "industry": "Telecommunications"}, 
    {"symbol": "VZ", "industry": "Telecommunications"}, 
    {"symbol": "AAP", "industry": "Insurance"}, 
    {"symbol": "MET", "industry": "Insurance"}, 
    {"symbol": "AIG", "industry": "Insurance"}, 
    {"symbol": "BRK-B", "industry": "Conglomerate"}, 
    {"symbol": "AVGO", "industry": "Tech"}, 
    {"symbol": "NFLX", "industry": "Entertainment"}, 
    {"symbol": "DIS", "industry": "Entertainment"}, 
    {"symbol": "ABNB", "industry": "Tech"}, 
    {"symbol": "IBM", "industry": "Tech"}, 
    {"symbol": "ORCL", "industry": "Tech"}, 
    {"symbol": "WMT", "industry": "Retail"}, 
    {"symbol": "JNJ", "industry": "Healthcare"}, 
    {"symbol": "HOOD", "industry": "Banks"} 
    ]

    for company in companies:
        save_financial_data(company["symbol"], 2020, 2024, output_dir, quarterly=True)

    combine_all_company_data(financial_data_folder, combined_file, csv_data_folder)
    clean_financial_data(os.path.join(csv_data_folder, combined_file), cleaned_file, csv_data_folder)
    generate_synthetic_data_with_randomness_and_range(
        os.path.join(csv_data_folder, cleaned_file),
        num_rows=5000,
        output_file=synthetic_file,
        output_folder=csv_data_folder
    )
    combine_real_and_synthetic_data(
        os.path.join(csv_data_folder, cleaned_file),
        os.path.join(csv_data_folder, synthetic_file),
        output_file=combined_real_and_synthetic_file,
        output_folder=csv_data_folder
    )
# Out:
# Fetching data for ticker: AAPL
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for AAPL
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for AAPL
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for AAPL
# Combined data for AAPL saved.
#
# Fetching data for ticker: MSFT
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for MSFT
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for MSFT
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for MSFT
# Combined data for MSFT saved.
#
# Fetching data for ticker: GOOG
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for GOOG
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for GOOG
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for GOOG
# Combined data for GOOG saved.
#
# Fetching data for ticker: NVDA
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for NVDA
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for NVDA
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for NVDA
# Combined data for NVDA saved.
#
# Fetching data for ticker: IBM
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for IBM
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for IBM
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for IBM
# Combined data for IBM saved.
#
# Fetching data for ticker: ORCL
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for ORCL
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for ORCL
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for ORCL
# Combined data for ORCL saved.
#
# Fetching data for ticker: JPM
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for JPM
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for JPM
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for JPM
# Combined data for JPM saved.
#
# Fetching data for ticker: BAC
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for BAC
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for BAC
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for BAC
# Combined data for BAC saved.
#
# Fetching data for ticker: WFC
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for WFC
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for WFC
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for WFC
# Combined data for WFC saved.
#
# Fetching data for ticker: C
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for C
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for C
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for C
# Combined data for C saved.
#
# Fetching data for ticker: GS
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for GS
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for GS
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for GS
# Combined data for GS saved.
#
# Fetching data for ticker: MS
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for MS
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for MS
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for MS
# Combined data for MS saved.
#
# Fetching data for ticker: XOM
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for XOM
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for XOM
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for XOM
# Combined data for XOM saved.
#
# Fetching data for ticker: CVX
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for CVX
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for CVX
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for CVX
# Combined data for CVX saved.
#
# Fetching data for ticker: SLB
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for SLB
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for SLB
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for SLB
# Combined data for SLB saved.
#
# Fetching data for ticker: COP
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for COP
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for COP
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for COP
# Combined data for COP saved.
#
# Fetching data for ticker: PG
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for PG
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for PG
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for PG
# Combined data for PG saved.
#
# Fetching data for ticker: PEP
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for PEP
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for PEP
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for PEP
# Combined data for PEP saved.
#
# Fetching data for ticker: KO
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for KO
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for KO
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for KO
# Combined data for KO saved.
#
# Fetching data for ticker: CL
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for CL
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for CL
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for CL
# Combined data for CL saved.
#
# Fetching data for ticker: UL
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for UL
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Attempting to retrieve income_stmt (Attempt 2/3)...
# Attempting to retrieve income_stmt (Attempt 3/3)...
# Failed to retrieve income_stmt for UL after 3 attempts.
# Attempting to retrieve cashflow (Attempt 1/3)...
# Attempting to retrieve cashflow (Attempt 2/3)...
# Attempting to retrieve cashflow (Attempt 3/3)...
# Failed to retrieve cashflow for UL after 3 attempts.
# Combined data for UL saved.
#
# Fetching data for ticker: PM
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for PM
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for PM
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for PM
# Combined data for PM saved.
#
# Fetching data for ticker: CAT
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for CAT
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for CAT
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for CAT
# Combined data for CAT saved.
#
# Fetching data for ticker: LMT
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for LMT
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for LMT
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for LMT
# Combined data for LMT saved.
#
# Fetching data for ticker: BA
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for BA
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for BA
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for BA
# Combined data for BA saved.
#
# Fetching data for ticker: RTX
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for RTX
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for RTX
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for RTX
# Combined data for RTX saved.
#
# Fetching data for ticker: GE
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for GE
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for GE
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for GE
# Combined data for GE saved.
#
# Fetching data for ticker: HON
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for HON
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for HON
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for HON
# Combined data for HON saved.
#
# Fetching data for ticker: SPG
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for SPG
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for SPG
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for SPG
# Combined data for SPG saved.
#
# Fetching data for ticker: PLD
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for PLD
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for PLD
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for PLD
# Combined data for PLD saved.
#
# Fetching data for ticker: O
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for O
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for O
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for O
# Combined data for O saved.
#
# Fetching data for ticker: EQR
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for EQR
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for EQR
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for EQR
# Combined data for EQR saved.
#
# Fetching data for ticker: VNO
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for VNO
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for VNO
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for VNO
# Combined data for VNO saved.
#
# Fetching data for ticker: BXP
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for BXP
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for BXP
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for BXP
# Combined data for BXP saved.
#
# Fetching data for ticker: TSLA
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for TSLA
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for TSLA
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for TSLA
# Combined data for TSLA saved.
#
# Fetching data for ticker: F
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for F
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for F
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for F
# Combined data for F saved.
#
# Fetching data for ticker: GM
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for GM
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for GM
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for GM
# Combined data for GM saved.
#
# Fetching data for ticker: RIVN
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for RIVN
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for RIVN
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for RIVN
# Combined data for RIVN saved.
#
# Fetching data for ticker: TM
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for TM
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for TM
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for TM
# Combined data for TM saved.
#
# Fetching data for ticker: HMC
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for HMC
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for HMC
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for HMC
# Combined data for HMC saved.
#
# Fetching data for ticker: JNJ
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for JNJ
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for JNJ
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for JNJ
# Combined data for JNJ saved.
#
# Fetching data for ticker: PFE
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for PFE
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for PFE
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for PFE
# Combined data for PFE saved.
#
# Fetching data for ticker: MRK
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for MRK
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for MRK
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for MRK
# Combined data for MRK saved.
#
# Fetching data for ticker: ABBV
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for ABBV
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for ABBV
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for ABBV
# Combined data for ABBV saved.
#
# Fetching data for ticker: TMO
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for TMO
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for TMO
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for TMO
# Combined data for TMO saved.
#
# Fetching data for ticker: DHR
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for DHR
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for DHR
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for DHR
# Combined data for DHR saved.
#
# Fetching data for ticker: AMZN
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for AMZN
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for AMZN
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for AMZN
# Combined data for AMZN saved.
#
# Fetching data for ticker: WMT
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for WMT
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for WMT
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for WMT
# Combined data for WMT saved.
#
# Fetching data for ticker: TGT
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for TGT
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for TGT
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for TGT
# Combined data for TGT saved.
#
# Fetching data for ticker: COST
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for COST
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for COST
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for COST
# Combined data for COST saved.
#
# Fetching data for ticker: HD
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for HD
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for HD
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for HD
# Combined data for HD saved.
#
# Fetching data for ticker: LOW
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for LOW
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for LOW
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for LOW
# Combined data for LOW saved.
#
# Fetching data for ticker: DIS
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for DIS
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for DIS
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for DIS
# Combined data for DIS saved.
#
# Fetching data for ticker: NFLX
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for NFLX
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for NFLX
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for NFLX
# Combined data for NFLX saved.
#
# Fetching data for ticker: CMCSA
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for CMCSA
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for CMCSA
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for CMCSA
# Combined data for CMCSA saved.
#
# Fetching data for ticker: VIA
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Attempting to retrieve balance_sheet (Attempt 2/3)...
# Attempting to retrieve balance_sheet (Attempt 3/3)...
# Failed to retrieve balance_sheet for VIA after 3 attempts.
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Attempting to retrieve income_stmt (Attempt 2/3)...
# Attempting to retrieve income_stmt (Attempt 3/3)...
# Failed to retrieve income_stmt for VIA after 3 attempts.
# Attempting to retrieve cashflow (Attempt 1/3)...
# Attempting to retrieve cashflow (Attempt 2/3)...
# Attempting to retrieve cashflow (Attempt 3/3)...
# Failed to retrieve cashflow for VIA after 3 attempts.
# No financial data retrieved for VIA
#
# Fetching data for ticker: FOX
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for FOX
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for FOX
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for FOX
# Combined data for FOX saved.
#
# Fetching data for ticker: SPOT
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for SPOT
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for SPOT
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for SPOT
# Combined data for SPOT saved.
#
# Fetching data for ticker: V
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for V
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for V
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for V
# Combined data for V saved.
#
# Fetching data for ticker: MA
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for MA
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for MA
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for MA
# Combined data for MA saved.
#
# Fetching data for ticker: PYPL
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for PYPL
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for PYPL
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for PYPL
# Combined data for PYPL saved.
#
# Fetching data for ticker: SQ
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for SQ
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for SQ
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for SQ
# Combined data for SQ saved.
#
# Fetching data for ticker: AXP
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for AXP
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for AXP
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for AXP
# Combined data for AXP saved.
#
# Fetching data for ticker: COF
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for COF
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for COF
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for COF
# Combined data for COF saved.
#
# Fetching data for ticker: INTC
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for INTC
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for INTC
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for INTC
# Combined data for INTC saved.
#
# Fetching data for ticker: AMD
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for AMD
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for AMD
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for AMD
# Combined data for AMD saved.
#
# Fetching data for ticker: TSM
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for TSM
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for TSM
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for TSM
# Combined data for TSM saved.
#
# Fetching data for ticker: ADBE
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for ADBE
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for ADBE
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for ADBE
# Combined data for ADBE saved.
#
# Fetching data for ticker: CRM
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for CRM
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for CRM
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for CRM
# Combined data for CRM saved.
#
# Fetching data for ticker: NOW
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for NOW
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for NOW
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for NOW
# Combined data for NOW saved.
#
# Fetching data for ticker: META
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for META
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for META
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for META
# Combined data for META saved.
#
# Fetching data for ticker: SNAP
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for SNAP
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for SNAP
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for SNAP
# Combined data for SNAP saved.
#
# Fetching data for ticker: TWTR
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Attempting to retrieve balance_sheet (Attempt 2/3)...
# Attempting to retrieve balance_sheet (Attempt 3/3)...
# Failed to retrieve balance_sheet for TWTR after 3 attempts.
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Attempting to retrieve income_stmt (Attempt 2/3)...
# Attempting to retrieve income_stmt (Attempt 3/3)...
# Failed to retrieve income_stmt for TWTR after 3 attempts.
# Attempting to retrieve cashflow (Attempt 1/3)...
# Attempting to retrieve cashflow (Attempt 2/3)...
# Attempting to retrieve cashflow (Attempt 3/3)...
# Failed to retrieve cashflow for TWTR after 3 attempts.
# No financial data retrieved for TWTR
#
# Fetching data for ticker: SHOP
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for SHOP
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for SHOP
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for SHOP
# Combined data for SHOP saved.
#
# Fetching data for ticker: NKE
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for NKE
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for NKE
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for NKE
# Combined data for NKE saved.
#
# Fetching data for ticker: ADDYY
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for ADDYY
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for ADDYY
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for ADDYY
# Combined data for ADDYY saved.
#
# Fetching data for ticker: RL
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for RL
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for RL
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for RL
# Combined data for RL saved.
#
# Fetching data for ticker: TIF
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Attempting to retrieve balance_sheet (Attempt 2/3)...
# Attempting to retrieve balance_sheet (Attempt 3/3)...
# Failed to retrieve balance_sheet for TIF after 3 attempts.
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Attempting to retrieve income_stmt (Attempt 2/3)...
# Attempting to retrieve income_stmt (Attempt 3/3)...
# Failed to retrieve income_stmt for TIF after 3 attempts.
# Attempting to retrieve cashflow (Attempt 1/3)...
# Attempting to retrieve cashflow (Attempt 2/3)...
# Attempting to retrieve cashflow (Attempt 3/3)...
# Failed to retrieve cashflow for TIF after 3 attempts.
# No financial data retrieved for TIF
#
# Fetching data for ticker: UPS
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for UPS
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for UPS
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for UPS
# Combined data for UPS saved.
#
# Fetching data for ticker: FDX
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for FDX
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for FDX
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for FDX
# Combined data for FDX saved.
#
# Fetching data for ticker: DHL
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Attempting to retrieve balance_sheet (Attempt 2/3)...
# Attempting to retrieve balance_sheet (Attempt 3/3)...
# Failed to retrieve balance_sheet for DHL after 3 attempts.
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Attempting to retrieve income_stmt (Attempt 2/3)...
# Attempting to retrieve income_stmt (Attempt 3/3)...
# Failed to retrieve income_stmt for DHL after 3 attempts.
# Attempting to retrieve cashflow (Attempt 1/3)...
# Attempting to retrieve cashflow (Attempt 2/3)...
# Attempting to retrieve cashflow (Attempt 3/3)...
# Failed to retrieve cashflow for DHL after 3 attempts.
# No financial data retrieved for DHL
#
# Fetching data for ticker: CSX
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for CSX
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for CSX
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for CSX
# Combined data for CSX saved.
#
# Fetching data for ticker: NSC
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for NSC
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for NSC
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for NSC
# Combined data for NSC saved.
#
# Fetching data for ticker: UNP
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for UNP
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for UNP
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for UNP
# Combined data for UNP saved.
#
# Fetching data for ticker: SO
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for SO
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for SO
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for SO
# Combined data for SO saved.
#
# Fetching data for ticker: DUK
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for DUK
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for DUK
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for DUK
# Combined data for DUK saved.
#
# Fetching data for ticker: NEE
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for NEE
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for NEE
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for NEE
# Combined data for NEE saved.
#
# Fetching data for ticker: D
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for D
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for D
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for D
# Combined data for D saved.
#
# Fetching data for ticker: EXC
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for EXC
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for EXC
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for EXC
# Combined data for EXC saved.
#
# Fetching data for ticker: PPL
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for PPL
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for PPL
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for PPL
# Combined data for PPL saved.
#
# Fetching data for ticker: MCD
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for MCD
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for MCD
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for MCD
# Combined data for MCD saved.
#
# Fetching data for ticker: YUM
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for YUM
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for YUM
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for YUM
# Combined data for YUM saved.
#
# Fetching data for ticker: SBUX
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for SBUX
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for SBUX
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for SBUX
# Combined data for SBUX saved.
#
# Fetching data for ticker: CMG
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for CMG
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for CMG
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for CMG
# Combined data for CMG saved.
#
# Fetching data for ticker: MELI
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for MELI
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for MELI
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for MELI
# Combined data for MELI saved.
#
# Fetching data for ticker: EBAY
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for EBAY
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for EBAY
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for EBAY
# Combined data for EBAY saved.
#
# Fetching data for ticker: ETSY
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for ETSY
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for ETSY
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for ETSY
# Combined data for ETSY saved.
#
# Fetching data for ticker: AZO
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for AZO
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for AZO
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for AZO
# Combined data for AZO saved.
#
# Fetching data for ticker: TJX
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for TJX
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for TJX
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for TJX
# Combined data for TJX saved.
#
# Fetching data for ticker: ROKU
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for ROKU
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for ROKU
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for ROKU
# Combined data for ROKU saved.
#
# Fetching data for ticker: DISCA
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Attempting to retrieve balance_sheet (Attempt 2/3)...
# Attempting to retrieve balance_sheet (Attempt 3/3)...
# Failed to retrieve balance_sheet for DISCA after 3 attempts.
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Attempting to retrieve income_stmt (Attempt 2/3)...
# Attempting to retrieve income_stmt (Attempt 3/3)...
# Failed to retrieve income_stmt for DISCA after 3 attempts.
# Attempting to retrieve cashflow (Attempt 1/3)...
# Attempting to retrieve cashflow (Attempt 2/3)...
# Attempting to retrieve cashflow (Attempt 3/3)...
# Failed to retrieve cashflow for DISCA after 3 attempts.
# No financial data retrieved for DISCA
#
# Fetching data for ticker: CHTR
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for CHTR
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for CHTR
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for CHTR
# Combined data for CHTR saved.
#
# Fetching data for ticker: T
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for T
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for T
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for T
# Combined data for T saved.
#
# Fetching data for ticker: VZ
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for VZ
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for VZ
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for VZ
# Combined data for VZ saved.
#
# Fetching data for ticker: AAP
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for AAP
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for AAP
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for AAP
# Combined data for AAP saved.
#
# Fetching data for ticker: MET
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for MET
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for MET
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for MET
# Combined data for MET saved.
#
# Fetching data for ticker: AIG
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for AIG
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for AIG
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for AIG
# Combined data for AIG saved.
#
# Fetching data for ticker: BRK-B
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for BRK-B
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for BRK-B
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for BRK-B
# Combined data for BRK-B saved.
#
# Fetching data for ticker: AVGO
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for AVGO
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for AVGO
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for AVGO
# Combined data for AVGO saved.
#
# Fetching data for ticker: NFLX
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for NFLX
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for NFLX
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for NFLX
# Combined data for NFLX saved.
#
# Fetching data for ticker: DIS
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for DIS
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for DIS
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for DIS
# Combined data for DIS saved.
#
# Fetching data for ticker: ABNB
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for ABNB
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for ABNB
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for ABNB
# Combined data for ABNB saved.
#
# Fetching data for ticker: IBM
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for IBM
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for IBM
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for IBM
# Combined data for IBM saved.
#
# Fetching data for ticker: ORCL
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for ORCL
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for ORCL
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for ORCL
# Combined data for ORCL saved.
#
# Fetching data for ticker: WMT
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for WMT
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for WMT
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for WMT
# Combined data for WMT saved.
#
# Fetching data for ticker: JNJ
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for JNJ
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for JNJ
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for JNJ
# Combined data for JNJ saved.
#
# Fetching data for ticker: HOOD
# Attempting to retrieve balance_sheet (Attempt 1/3)...
# Retrieved balance_sheet data for HOOD
# Attempting to retrieve income_stmt (Attempt 1/3)...
# Retrieved income_stmt data for HOOD
# Attempting to retrieve cashflow (Attempt 1/3)...
# Retrieved cashflow data for HOOD
# Combined data for HOOD saved.
# Combined data saved to Cash Flow Prediction Dataset/csv_data/combined_financial_data.csv
# Cleaned financial data saved to Cash Flow Prediction Dataset/csv_data/cleaned_financial_data.csv
# /Users/abduljalaalabubakar/miniforge3/lib/python3.10/site-packages/sdv/single_table/base.py:119: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# /Users/abduljalaalabubakar/miniforge3/lib/python3.10/site-packages/sdv/single_table/base.py:104: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(
# Synthetic data (80% randomness with range constraints) saved to Cash Flow Prediction Dataset/csv_data/synthetic_financial_data.csv
# Combined real and synthetic data saved to Cash Flow Prediction Dataset/csv_data/combined_real_and_synthetic_data.csv

# %% [markdown]
# # CREATING THE CASH FLOW PREDICTION MODEL
#
# This model should enable us predict the quarterly cash flows of companies using their bank statements

# %%
warnings.filterwarnings("ignore")

# Setting a consistent random seed for reproducibility
SEED = 42
np.random.seed(SEED)

# The Path to the dataset
dataset_path = r'/Users/abduljalaalabubakar/Desktop/Projects/Symply Finance/Finance Model/Cash Flow Prediction Dataset/csv_data/combined_real_and_synthetic_data.csv'

# Loading the dataset
df = pd.read_csv(dataset_path)

# Adding synthetic features if missing
if 'balance_sheet_Total Assets' not in df.columns:
    print("Adding synthetic 'balance_sheet_Total Assets' column.")
    df['balance_sheet_Total Assets'] = (
        df.get('balance_sheet_Accounts Payable', np.random.uniform(100_000, 1_000_000, len(df))) +
        df.get('balance_sheet_Accounts Receivable', np.random.uniform(100_000, 1_000_000, len(df))) +
        df.get('cashflow_Operating Cash Flow', np.random.uniform(100_000, 1_000_000, len(df)))
    )

if 'balance_sheet_Total Current Assets' not in df.columns:
    print("Adding synthetic 'balance_sheet_Total Current Assets' column.")
    df['balance_sheet_Total Current Assets'] = (
        df.get('balance_sheet_Accounts Receivable', np.random.uniform(100_000, 1_000_000, len(df))) +
        np.random.randint(100_000, 1_000_000_000, size=len(df))
    )

if 'balance_sheet_Total Current Liabilities' not in df.columns:
    print("Generating synthetic 'balance_sheet_Total Current Liabilities' column.")
    df['balance_sheet_Total Current Liabilities'] = np.random.randint(
        low=100_000, high=1_000_000_000, size=len(df)
    )

# Handling divisions by zero and invalid values
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# Feature Engineering
df['Current_Ratio'] = np.where(
    df['balance_sheet_Total Current Liabilities'] > 0,
    df['balance_sheet_Total Current Assets'] / df['balance_sheet_Total Current Liabilities'],
    0
)

df['Quick_Ratio'] = np.where(
    df['balance_sheet_Total Current Liabilities'] > 0,
    (df['balance_sheet_Total Current Assets'] - df.get('balance_sheet_Inventory', 0)) / df['balance_sheet_Total Current Liabilities'],
    0
)

df['Debt_to_Equity'] = np.where(
    df['balance_sheet_Total Assets'] > 0,
    df['balance_sheet_Accounts Payable'] / df['balance_sheet_Total Assets'],
    0
)

df['Return_on_Assets'] = np.where(
    df['balance_sheet_Total Assets'] > 0,
    df['income_stmt_Net Income'] / df['balance_sheet_Total Assets'],
    0
)

df['Operating_Margin'] = np.where(
    df['income_stmt_Total Revenue'] > 0,
    df['income_stmt_Gross Profit'] / df['income_stmt_Total Revenue'],
    0
)

# Lagged Features
df['Lagged_Revenue'] = df['income_stmt_Total Revenue'].shift(1).fillna(0)
df['Lagged_Net_Income'] = df['income_stmt_Net Income'].shift(1).fillna(0)
df['Lagged_Operating_Cash_Flow'] = df['cashflow_Operating Cash Flow'].shift(1).fillna(0)

# Interaction Features
df['Interaction_Current_Quick'] = df['Current_Ratio'] * df['Quick_Ratio']
df['Interaction_Return_Debt'] = df['Return_on_Assets'] * df['Debt_to_Equity']

# Removing NaN values introduced by feature engineering
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)

# Target Variable
target_variable = 'cashflow_Operating Cash Flow'

# Handling negative or zero values in the target variable before scaling
df = df[df[target_variable] > 0]

# Normalizing Target Variable using StandardScaler
scaler_y = StandardScaler()
df[target_variable] = scaler_y.fit_transform(df[[target_variable]])

# Features to include
initial_features = [
    'Current_Ratio', 'Quick_Ratio', 'Debt_to_Equity', 'Return_on_Assets',
    'Operating_Margin', 'Lagged_Revenue', 'Lagged_Net_Income', 'Lagged_Operating_Cash_Flow',
    'Interaction_Current_Quick', 'Interaction_Return_Debt'
]

# Multicollinearity Check and Removal
correlation_matrix = df[initial_features].corr().abs()
upper_tri = correlation_matrix.where(np.triu(np.ones(correlation_matrix.shape), k=1).astype(bool))
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.95)]
df.drop(columns=to_drop, inplace=True)
features = [feature for feature in initial_features if feature not in to_drop]

# Splitting the dataset
X = df[features]
y = df[target_variable]

# Normalizing the features using PowerTransformer
scaler_X = PowerTransformer()
X_transformed = scaler_X.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_transformed, y, test_size=0.2, random_state=SEED)

# Model training with multiple regressors
models = {
    'RandomForest': RandomForestRegressor(random_state=SEED),
    'GradientBoosting': GradientBoostingRegressor(random_state=SEED),
    'AdaBoost': AdaBoostRegressor(random_state=SEED)
}

best_model = None
best_r2 = -np.inf

# Perform GridSearch and Cross-Validation
kf = KFold(n_splits=5, shuffle=True, random_state=SEED)
for model_name, model in models.items():
    print(f"Training {model_name}...")
    param_grid = {
        'n_estimators': [100, 200, 300],
        'max_depth': [5, 10, 15],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
    } if model_name == 'RandomForest' else {
        'n_estimators': [100, 200, 300],
        'learning_rate': [0.01, 0.05, 0.1],
        'max_depth': [3, 5, 7],
    } if model_name == 'GradientBoosting' else {
        'n_estimators': [50, 100, 200],
        'learning_rate': [0.01, 0.1, 1.0],
    }
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=kf, n_jobs=-1, scoring='r2')
    grid_search.fit(X_train, y_train)
    best_estimator = grid_search.best_estimator_

    # Predictions
    y_pred = best_estimator.predict(X_test)

    # Evaluation
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    print(f"{model_name} - Mean Squared Error: {mse:.4f}, R-Squared: {r2:.4f}")

    if r2 > best_r2:
        best_r2 = r2
        best_model = best_estimator

# Saving the best model and preprocessed dataset
output_dir = 'Cash_Flow_Prediction_Model'
os.makedirs(output_dir, exist_ok=True)
df.to_csv(os.path.join(output_dir, 'preprocessed_dataset.csv'), index=False)

with open(os.path.join(output_dir, 'cash_flow_model.pkl'), 'wb') as f:
    pickle.dump(best_model, f)

print("Best model and preprocessed dataset saved successfully.")
# Out:
# Adding synthetic 'balance_sheet_Total Assets' column.
# Adding synthetic 'balance_sheet_Total Current Assets' column.
# Generating synthetic 'balance_sheet_Total Current Liabilities' column.
# Training RandomForest...
# RandomForest - Mean Squared Error: 0.1848, R-Squared: 0.8010
# Training GradientBoosting...
# GradientBoosting - Mean Squared Error: 0.3370, R-Squared: 0.6370
# Training AdaBoost...
# AdaBoost - Mean Squared Error: 0.1734, R-Squared: 0.8132
# Best model and preprocessed dataset saved successfully.
